# %% [markdown]
# # Name: Chandra Kiran Billingi
# ## Course Title: MSCS 634 - Advanced Big Data and Data Mining
# ### Lab 1: Data Visualization, Data Preprocessing, and Statistical Analysis Using Python

# %%
# Step 1: Data Collection

# %%
import pandas as pd
df = pd.read_csv('austin_weather.csv')

# %%
# This will Replace empty strings or whitespace-only cells with np.nan across the entire DataFrame
import numpy as np


df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0  2013-12-21         74        60        45           67.0          49.0
# 1  2013-12-22         56        48        39           43.0          36.0
# 2  2013-12-23         58        45        32           31.0          27.0
# 3  2013-12-24         61        46        31           36.0          28.0
# 4  2013-12-25         58        50        41           44.0          40.0
#
#    DewPointLowF  HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0          43.0                 93.0                75.0                57.0
# 1          28.0                 93.0                68.0                43.0
# 2          23.0                 76.0                52.0                27.0
# 3          21.0                 89.0                56.0                22.0
# 4          36.0                 86.0                71.0                56.0
#
# ...

# %%
df
# Out:
#             Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0     2013-12-21         74        60        45           67.0          49.0
# 1     2013-12-22         56        48        39           43.0          36.0
# 2     2013-12-23         58        45        32           31.0          27.0
# 3     2013-12-24         61        46        31           36.0          28.0
# 4     2013-12-25         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314  2017-07-27        103        89        75           71.0          67.0
# 1315  2017-07-28        105        91        76           71.0          64.0
# 1316  2017-07-29        107        92        77           72.0          64.0
# 1317  2017-07-30        106        93        79           70.0          68.0
# 1318  2017-07-31         99        88        77           66.0          61.0
#
# ...

# %%
# Step 2: Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram (distribution of high temperatures)
df["TempHighF"].hist(bins=20)
plt.title("Distribution of High Temperatures")
plt.xlabel("TempHighF")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="TempHighF", y="DewPointHighF", alpha=0.6)
plt.title("Scatter Plot: TempHighF vs DewPointHighF")
plt.xlabel("High Temperature (F)")
plt.ylabel("High Dew Point (F)")
plt.grid(True)
plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"], errors='coerce')
df_sorted = df.sort_values("Date")

plt.figure(figsize=(12, 5))
plt.plot(df_sorted["Date"], df_sorted["TempHighF"], color="orange")
plt.title("Line Plot: High Temperature Over Time")
plt.xlabel("Date")
plt.ylabel("High Temperature (F)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
#Step 3: Data Preprocessing

# %%
# 1. Handling Missing Values:
df.isnull().sum()
# Out:
# Date                            0
# TempHighF                       0
# TempAvgF                        0
# TempLowF                        0
# DewPointHighF                   7
# DewPointAvgF                    7
# DewPointLowF                    7
# HumidityHighPercent             2
# HumidityAvgPercent              2
# HumidityLowPercent              2
# SeaLevelPressureHighInches      3
# SeaLevelPressureAvgInches       3
# SeaLevelPressureLowInches       3
# VisibilityHighMiles            12
# VisibilityAvgMiles             12
# VisibilityLowMiles             83
# WindHighMPH                     2
# WindAvgMPH                      2
# WindGustMPH                     4
# PrecipitationSumInches          0
# Events                        903
# dtype: int64

# %%
# printing values before the updation with mean
print(df.iloc[166:192,1:7])
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF
# 166         91        83        74           72.0          70.0          68.0
# 167         92        83        73           71.0          70.0          69.0
# 168         92        83        74           72.0          70.0          67.0
# 169         90        83        76           72.0          70.0          64.0
# 170         86        77        68           75.0          71.0          66.0
# 171         92        78        64           70.0          61.0          56.0
# 172         94        80        66           73.0          66.0          62.0
# 173         92        80        68           74.0          72.0          67.0
# 174         89        79        68            NaN           NaN           NaN
# 175         87        92        73            NaN           NaN           NaN
# 176         91        83        74            NaN           NaN           NaN
# ...

# %%
mean_value = df['DewPointHighF'].mean()
df['DewPointHighF'] = df['DewPointHighF'].fillna(mean_value)

mean_value = df['DewPointAvgF'].mean()
df['DewPointAvgF'] = df['DewPointAvgF'].fillna(mean_value)

mean_value = df['DewPointLowF'].mean()
df['DewPointLowF'] = df['DewPointLowF'].fillna(mean_value)

mean_value = df['HumidityHighPercent'].mean()
df['HumidityHighPercent'] = df['HumidityHighPercent'].fillna(mean_value)

mean_value = df['HumidityAvgPercent'].mean()
df['HumidityAvgPercent'] = df['HumidityAvgPercent'].fillna(mean_value)

mean_value = df['HumidityLowPercent'].mean()
df['HumidityLowPercent'] = df['HumidityLowPercent'].fillna(mean_value)

mean_value = df['SeaLevelPressureHighInches'].mean()
df['SeaLevelPressureHighInches'] = df['SeaLevelPressureHighInches'].fillna(mean_value)

mean_value = df['SeaLevelPressureAvgInches'].mean()
df['SeaLevelPressureAvgInches'] = df['SeaLevelPressureAvgInches'].fillna(mean_value)

mean_value = df['SeaLevelPressureLowInches'].mean()
df['SeaLevelPressureLowInches'] = df['SeaLevelPressureLowInches'].fillna(mean_value)

mean_value = df['VisibilityHighMiles'].mean()
df['VisibilityHighMiles'] = df['VisibilityHighMiles'].fillna(mean_value)

mean_value = df['VisibilityAvgMiles'].mean()
df['VisibilityAvgMiles'] = df['VisibilityAvgMiles'].fillna(mean_value)

mean_value = df['VisibilityLowMiles'].mean()
df['VisibilityLowMiles'] = df['VisibilityLowMiles'].fillna(mean_value)

mean_value = df['WindHighMPH'].mean()
df['WindHighMPH'] = df['WindHighMPH'].fillna(mean_value)

mean_value = df['WindAvgMPH'].mean()
df['WindAvgMPH'] = df['WindAvgMPH'].fillna(mean_value)

mean_value = df['WindGustMPH'].mean()
df['WindGustMPH'] = df['WindGustMPH'].fillna(mean_value)

# %%
# printing values after the updation with mean
print(df.iloc[166:192,1:7])
# Out:
#      TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF
# 166         91        83        74      72.000000     70.000000     68.000000
# 167         92        83        73      71.000000     70.000000     69.000000
# 168         92        83        74      72.000000     70.000000     67.000000
# 169         90        83        76      72.000000     70.000000     64.000000
# 170         86        77        68      75.000000     71.000000     66.000000
# 171         92        78        64      70.000000     61.000000     56.000000
# 172         94        80        66      73.000000     66.000000     62.000000
# 173         92        80        68      74.000000     72.000000     67.000000
# 174         89        79        68      61.515244     56.632622     50.933689
# 175         87        92        73      61.515244     56.632622     50.933689
# 176         91        83        74      61.515244     56.632622     50.933689
# ...

# %%
# 2. Outlier Detection and Removal:

# %%
df
# Out:
#             Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0     2013-12-21         74        60        45           67.0          49.0
# 1     2013-12-22         56        48        39           43.0          36.0
# 2     2013-12-23         58        45        32           31.0          27.0
# 3     2013-12-24         61        46        31           36.0          28.0
# 4     2013-12-25         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314  2017-07-27        103        89        75           71.0          67.0
# 1315  2017-07-28        105        91        76           71.0          64.0
# 1316  2017-07-29        107        92        77           72.0          64.0
# 1317  2017-07-30        106        93        79           70.0          68.0
# 1318  2017-07-31         99        88        77           66.0          61.0
#
# ...

# %%
# List of columns for outlier detection
cols = [
    'DewPointHighF', 'DewPointAvgF', 'DewPointLowF',
    'HumidityHighPercent', 'HumidityAvgPercent', 'HumidityLowPercent',
    'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches', 'SeaLevelPressureLowInches',
    'VisibilityHighMiles', 'VisibilityAvgMiles', 'VisibilityLowMiles',
    'WindHighMPH', 'WindAvgMPH', 'WindGustMPH'
]

# Ensure columns are numeric
for col in cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Store indices of outliers for reporting
outlier_indices = set()

# Detect and remove outliers column by column
for col in cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}:")
    print(f"  Q1  = {Q1}")
    print(f"  Q3  = {Q3}")
    print(f"  IQR = {IQR}")
    print(f"  Outliers found: {outliers.shape[0]}\n")
    outlier_indices.update(outliers.index.tolist())

# Remove all rows that are outliers in any of the columns
df_clean = df.drop(index=outlier_indices)

print(f"Total rows removed: {len(outlier_indices)}")
print(f"Remaining rows: {df_clean.shape[0]}")
# Out:
# DewPointHighF:
#   Q1  = 53.0
#   Q3  = 73.0
#   IQR = 20.0
#   Outliers found: 10
#
# DewPointAvgF:
#   Q1  = 46.5
#   Q3  = 69.0
#   IQR = 22.5
#   Outliers found: 6
#
# DewPointLowF:
#   Q1  = 38.0
#   Q3  = 65.0
#   IQR = 27.0
#   Outliers found: 0
#
# HumidityHighPercent:
#   Q1  = 85.0
#   Q3  = 94.0
#   IQR = 9.0
#   Outliers found: 124
#
# HumidityAvgPercent:
#   Q1  = 59.0
#   Q3  = 74.0
#   IQR = 15.0
#   Outliers found: 23
#
# HumidityLowPercent:
#   Q1  = 33.0
#   Q3  = 55.0
#   IQR = 22.0
#   Outliers found: 14
#
# SeaLevelPressureHighInches:
#   Q1  = 29.99
#   Q3  = 30.205
#   IQR = 0.21499999999999986
#   Outliers found: 37
#
# SeaLevelPressureAvgInches:
#   Q1  = 29.91
#   Q3  = 30.1
#   IQR = 0.19000000000000128
#   Outliers found: 57
#
# SeaLevelPressureLowInches:
#   Q1  = 29.82
#   Q3  = 30.02
#   IQR = 0.1999999999999993
#   Outliers found: 40
#
# VisibilityHighMiles:
#   Q1  = 10.0
#   Q3  = 10.0
#   IQR = 0.0
#   Outliers found: 17
#
# VisibilityAvgMiles:
# ...

# %%
# 3. Data Reduction

# %%
# Sampling the data with 80% of rows
df_sampled = df.sample(frac=0.8, random_state=1)

# %%
df_sampled
# Out:
#            Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 288  2014-10-05         87        75        62      67.000000     62.000000
# 190  2014-06-29         95        86        77      74.000000     73.000000
# 852  2016-04-21         83        72        60      66.000000     61.000000
# 596  2015-08-09        103        89        74      61.515244     56.632622
# 186  2014-06-25         89        80        71      76.000000     72.000000
# ..          ...        ...       ...       ...            ...           ...
# 565  2015-07-09         93        85        76      74.000000     71.000000
# 249  2014-08-27         98        87        76      72.000000     66.000000
# 476  2015-04-11         70        65        59      66.000000     62.000000
# 781  2016-02-10         74        56        38      36.000000     33.000000
# 454  2015-03-20         71        64        57      67.000000     61.000000
#
# ...

# %%
df_sampled.to_csv('sampled_austin_weather.csv', index=False)

# %%
# printing column values as a NumPy array
print(df_sampled.columns.values)
# Out:
# ['Date' 'TempHighF' 'TempAvgF' 'TempLowF' 'DewPointHighF' 'DewPointAvgF'
#  'DewPointLowF' 'HumidityHighPercent' 'HumidityAvgPercent'
#  'HumidityLowPercent' 'SeaLevelPressureHighInches'
#  'SeaLevelPressureAvgInches' 'SeaLevelPressureLowInches'
#  'VisibilityHighMiles' 'VisibilityAvgMiles' 'VisibilityLowMiles'
#  'WindHighMPH' 'WindAvgMPH' 'WindGustMPH' 'PrecipitationSumInches'
#  'Events']

# %%
df_sampled
# Out:
#            Date  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 288  2014-10-05         87        75        62      67.000000     62.000000
# 190  2014-06-29         95        86        77      74.000000     73.000000
# 852  2016-04-21         83        72        60      66.000000     61.000000
# 596  2015-08-09        103        89        74      61.515244     56.632622
# 186  2014-06-25         89        80        71      76.000000     72.000000
# ..          ...        ...       ...       ...            ...           ...
# 565  2015-07-09         93        85        76      74.000000     71.000000
# 249  2014-08-27         98        87        76      72.000000     66.000000
# 476  2015-04-11         70        65        59      66.000000     62.000000
# 781  2016-02-10         74        56        38      36.000000     33.000000
# 454  2015-03-20         71        64        57      67.000000     61.000000
#
# ...

# %%
# Perform dimension elimination by dropping less relevant columns.

df_reduced = df_sampled.drop(['TempAvgF', 'DewPointAvgF', 'HumidityAvgPercent', 'SeaLevelPressureAvgInches', 'VisibilityAvgMiles', 'WindAvgMPH'], axis=1)

# %%
# printing column values as a NumPy array
print(df_reduced.columns.values)
# Out:
# ['Date' 'TempHighF' 'TempLowF' 'DewPointHighF' 'DewPointLowF'
#  'HumidityHighPercent' 'HumidityLowPercent' 'SeaLevelPressureHighInches'
#  'SeaLevelPressureLowInches' 'VisibilityHighMiles' 'VisibilityLowMiles'
#  'WindHighMPH' 'WindGustMPH' 'PrecipitationSumInches' 'Events']

# %%
df_reduced
# Out:
#            Date  TempHighF  TempLowF  DewPointHighF  DewPointLowF  \
# 288  2014-10-05         87        62      67.000000     56.000000
# 190  2014-06-29         95        77      74.000000     70.000000
# 852  2016-04-21         83        60      66.000000     58.000000
# 596  2015-08-09        103        74      61.515244     50.933689
# 186  2014-06-25         89        71      76.000000     68.000000
# ..          ...        ...       ...            ...           ...
# 565  2015-07-09         93        76      74.000000     66.000000
# 249  2014-08-27         98        76      72.000000     56.000000
# 476  2015-04-11         70        59      66.000000     53.000000
# 781  2016-02-10         74        38      36.000000     30.000000
# 454  2015-03-20         71        57      67.000000     55.000000
#
#      HumidityHighPercent  HumidityLowPercent  SeaLevelPressureHighInches  \
# 288                 93.0                44.0                   29.980000
# ...

# %%
df_reduced.to_csv('reduced_austin_weather.csv', index=False)

# %%
# 4. Data Scaling and Discretization

# %%
# data before scaling
df_reduced
# Out:
#            Date  TempHighF  TempLowF  DewPointHighF  DewPointLowF  \
# 288  2014-10-05         87        62      67.000000     56.000000
# 190  2014-06-29         95        77      74.000000     70.000000
# 852  2016-04-21         83        60      66.000000     58.000000
# 596  2015-08-09        103        74      61.515244     50.933689
# 186  2014-06-25         89        71      76.000000     68.000000
# ..          ...        ...       ...            ...           ...
# 565  2015-07-09         93        76      74.000000     66.000000
# 249  2014-08-27         98        76      72.000000     56.000000
# 476  2015-04-11         70        59      66.000000     53.000000
# 781  2016-02-10         74        38      36.000000     30.000000
# 454  2015-03-20         71        57      67.000000     55.000000
#
#      HumidityHighPercent  HumidityLowPercent  SeaLevelPressureHighInches  \
# 288                 93.0                44.0                   29.980000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# Convert non-numeric values (like 'T') to NaN, then convert all to numeric
numeric_cols = [
    'TempHighF', 'TempLowF', 'DewPointHighF', 'DewPointLowF',
    'HumidityHighPercent', 'HumidityLowPercent',
    'SeaLevelPressureHighInches', 'SeaLevelPressureLowInches',
    'VisibilityHighMiles', 'VisibilityLowMiles',
    'WindHighMPH', 'WindGustMPH'
]

# Convert columns to numeric (if not already)
for col in numeric_cols:
    df_reduced[col] = pd.to_numeric(df_reduced[col], errors='coerce')

# Apply Min-Max Scaling
scaler = MinMaxScaler()
df_scaled = df_reduced.copy()
df_scaled[numeric_cols] = scaler.fit_transform(df_reduced[numeric_cols])

# Show the scaled data
df_scaled[numeric_cols]
# Out:
#      TempHighF  TempLowF  DewPointHighF  DewPointLowF  HumidityHighPercent  \
# 288   0.733333  0.693548       0.805970      0.739726             0.888889
# 190   0.840000  0.935484       0.910448      0.931507             0.809524
# 852   0.680000  0.661290       0.791045      0.767123             0.888889
# 596   0.946667  0.887097       0.724108      0.670325             1.000000
# 186   0.760000  0.838710       0.940299      0.904110             0.904762
# ..         ...       ...            ...           ...                  ...
# 565   0.813333  0.919355       0.910448      0.876712             0.809524
# 249   0.880000  0.919355       0.880597      0.739726             0.793651
# 476   0.506667  0.645161       0.791045      0.698630             1.000000
# 781   0.560000  0.306452       0.343284      0.383562             0.714286
# 454   0.520000  0.612903       0.805970      0.726027             0.888889
#
#      HumidityLowPercent  SeaLevelPressureHighInches  \
# ...

# %%
# save the scaled data into a csv file
df_scaled.to_csv('min_max_scaled_austin_weather.csv', index=False)

# %%
# Discretization (Binning into Low, Medium, High)
columns_to_bin = ['TempHighF', 'TempLowF', 'DewPointHighF',
                  'HumidityHighPercent', 'VisibilityLowMiles', 'WindHighMPH']

for col in columns_to_bin:
    binned_col = col + "_binned"
    df_scaled[binned_col] = pd.cut(df_scaled[col], bins=3, labels=["Low", "Medium", "High"])

# Show the discretized columns
print(df_scaled[[col + "_binned" for col in columns_to_bin]].head())

# Optionally, save the updated DataFrame to a new CSV
df_scaled.to_csv("austin_weather_scaled_binned_after_Discretization.csv", index=False)
# Out:
#     TempHighF_binned TempLowF_binned DewPointHighF_binned  \
# 288             High            High                 High
# 190             High            High                 High
# 852             High          Medium                 High
# 596             High            High                 High
# 186             High            High                 High
#
#     HumidityHighPercent_binned VisibilityLowMiles_binned WindHighMPH_binned
# 288                       High                      High             Medium
# 190                       High                    Medium             Medium
# 852                       High                       Low             Medium
# 596                       High                      High                Low
# 186                       High                      High             Medium

# %%
#  Step 4: Statistical Analysis

# %%
# 1. General Overview of Data:
df_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1055 entries, 288 to 454
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1055 non-null   object
#  1   TempHighF                   1055 non-null   float64
#  2   TempLowF                    1055 non-null   float64
#  3   DewPointHighF               1055 non-null   float64
#  4   DewPointLowF                1055 non-null   float64
#  5   HumidityHighPercent         1055 non-null   float64
#  6   HumidityLowPercent          1055 non-null   float64
#  7   SeaLevelPressureHighInches  1055 non-null   float64
#  8   SeaLevelPressureLowInches   1055 non-null   float64
#  9   VisibilityHighMiles         1055 non-null   float64
#  10  VisibilityLowMiles          1055 non-null   float64
#  11  WindHighMPH                 1055 non-null   float64
#  12  WindGustMPH                 1055 non-null   float64
# ...

# %%
df_scaled.describe()
# Out:
#          TempHighF     TempLowF  DewPointHighF  DewPointLowF  \
# count  1055.000000  1055.000000    1055.000000   1055.000000
# mean      0.646306     0.653509       0.718859      0.665541
# std       0.199951     0.231435       0.204712      0.223496
# min       0.000000     0.000000       0.000000      0.000000
# 25%       0.520000     0.483871       0.582090      0.493151
# 50%       0.680000     0.693548       0.776119      0.726027
# 75%       0.800000     0.854839       0.895522      0.863014
# max       1.000000     1.000000       1.000000      1.000000
#
#        HumidityHighPercent  HumidityLowPercent  SeaLevelPressureHighInches  \
# count          1055.000000         1055.000000                 1055.000000
# mean              0.807867            0.419277                    0.405708
# std               0.173352            0.201809                    0.152678
# min               0.000000            0.000000                    0.000000
# ...

# %%
from matplotlib import pyplot as plt
_df_11['DewPointLowF'].plot(kind='line', figsize=(8, 4), title='DewPointLowF')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_7.plot(kind='scatter', x='DewPointLowF', y='HumidityHighPercent', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['DewPointLowF'].plot(kind='hist', bins=20, title='DewPointLowF')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# 2. Central Tendency Measures


scaled_numeric_cols = [
    'TempHighF', 'TempLowF', 'DewPointHighF', 'DewPointLowF',
    'HumidityHighPercent', 'HumidityLowPercent',
    'SeaLevelPressureHighInches', 'SeaLevelPressureLowInches',
    'VisibilityHighMiles', 'VisibilityLowMiles',
    'WindHighMPH', 'WindGustMPH'
]

# Create a new DataFrame to store the results
central_tendency = pd.DataFrame(index=scaled_numeric_cols)

# Compute statistics
central_tendency["Min"] = df_scaled[scaled_numeric_cols].min()
central_tendency["Max"] = df_scaled[scaled_numeric_cols].max()
central_tendency["Mean"] = df_scaled[scaled_numeric_cols].mean()
central_tendency["Median"] = df_scaled[scaled_numeric_cols].median()
central_tendency["Mode"] = df_scaled[scaled_numeric_cols].mode().iloc[0]  # mode() returns a DataFrame

# Display the result
central_tendency
# Out:
#                             Min  Max      Mean    Median      Mode
# TempHighF                   0.0  1.0  0.646306  0.680000  0.720000
# TempLowF                    0.0  1.0  0.653509  0.693548  0.903226
# DewPointHighF               0.0  1.0  0.718859  0.776119  0.910448
# DewPointLowF                0.0  1.0  0.665541  0.726027  0.876712
# HumidityHighPercent         0.0  1.0  0.807867  0.841270  1.000000
# HumidityLowPercent          0.0  1.0  0.419277  0.409639  0.506024
# SeaLevelPressureHighInches  0.0  1.0  0.405708  0.375000  0.358333
# SeaLevelPressureLowInches   0.0  1.0  0.438867  0.425000  0.391667
# VisibilityHighMiles         0.0  1.0  0.998088  1.000000  1.000000
# VisibilityLowMiles          0.0  1.0  0.696585  0.888889  1.000000
# WindHighMPH                 0.0  1.0  0.312197  0.304348  0.260870
# WindGustMPH                 0.0  1.0  0.254702  0.229167  0.229167

# %%
# List of scaled numerical columns
scaled_numeric_cols = [
    'TempHighF', 'TempLowF', 'DewPointHighF', 'DewPointLowF',
    'HumidityHighPercent', 'HumidityLowPercent',
    'SeaLevelPressureHighInches', 'SeaLevelPressureLowInches',
    'VisibilityHighMiles', 'VisibilityLowMiles',
    'WindHighMPH', 'WindGustMPH'
]

# Create a new DataFrame to store dispersion measures
dispersion = pd.DataFrame(index=scaled_numeric_cols)

# Compute dispersion metrics
dispersion["Range"] = df_scaled[scaled_numeric_cols].max() - df_scaled[scaled_numeric_cols].min()
dispersion["Q1"] = df_scaled[scaled_numeric_cols].quantile(0.25)
dispersion["Q3"] = df_scaled[scaled_numeric_cols].quantile(0.75)
dispersion["IQR"] = dispersion["Q3"] - dispersion["Q1"]
dispersion["Variance"] = df_scaled[scaled_numeric_cols].var()
dispersion["StdDev"] = df_scaled[scaled_numeric_cols].std()

# Display the result
dispersion
# Out:
#                             Range        Q1        Q3       IQR  Variance  \
# TempHighF                     1.0  0.520000  0.800000  0.280000  0.039981
# TempLowF                      1.0  0.483871  0.854839  0.370968  0.053562
# DewPointHighF                 1.0  0.582090  0.895522  0.313433  0.041907
# DewPointLowF                  1.0  0.493151  0.863014  0.369863  0.049950
# HumidityHighPercent           1.0  0.761905  0.904762  0.142857  0.030051
# HumidityLowPercent            1.0  0.277108  0.542169  0.265060  0.040727
# SeaLevelPressureHighInches    1.0  0.308333  0.483333  0.175000  0.023310
# SeaLevelPressureLowInches     1.0  0.350000  0.508333  0.158333  0.020761
# VisibilityHighMiles           1.0  1.000000  1.000000  0.000000  0.001287
# VisibilityLowMiles            1.0  0.444444  1.000000  0.555556  0.129867
# WindHighMPH                   1.0  0.173913  0.391304  0.217391  0.022487
# WindGustMPH                   1.0  0.166667  0.333333  0.166667  0.015068
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# List of scaled numeric columns
scaled_numeric_cols = [
    'TempHighF', 'TempLowF', 'DewPointHighF', 'DewPointLowF',
    'HumidityHighPercent', 'HumidityLowPercent',
    'SeaLevelPressureHighInches', 'SeaLevelPressureLowInches',
    'VisibilityHighMiles', 'VisibilityLowMiles',
    'WindHighMPH', 'WindGustMPH'
]

# Compute the correlation matrix
correlation_matrix = df_scaled[scaled_numeric_cols].corr()

# Display the matrix as a DataFrame
print(correlation_matrix)

# Optional: Heatmap Visualization (recommended for screenshots)
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Scaled Numerical Features")
plt.tight_layout()
plt.show()
# Out:
#                             TempHighF  TempLowF  DewPointHighF  DewPointLowF  \
# TempHighF                    1.000000  0.884430       0.815852      0.770609
# TempLowF                     0.884430  1.000000       0.903617      0.918198
# DewPointHighF                0.815852  0.903617       1.000000      0.894781
# DewPointLowF                 0.770609  0.918198       0.894781      1.000000
# HumidityHighPercent          0.148364  0.285518       0.518178      0.484933
# HumidityLowPercent          -0.247108  0.082686       0.249129      0.348635
# SeaLevelPressureHighInches  -0.676072 -0.673185      -0.707934     -0.654530
# SeaLevelPressureLowInches   -0.539885 -0.515873      -0.619333     -0.476342
# VisibilityHighMiles          0.101288  0.077599       0.049260      0.044741
# VisibilityLowMiles           0.199538  0.006536      -0.152887     -0.116907
# WindHighMPH                  0.006623  0.016346       0.098258     -0.032103
# ...
